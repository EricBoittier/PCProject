# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import prody_ as pr
#Parameters
#sequence="GLY"
sequence="SER"
#temp=[298]
#temp=[328]
#temp=[358]
temp=[400]
#temp=[298, 328, 358]
#temp=[298, 328, 358, 400]
wb=True
wb=False

n=100n

pr.getstartingpdb(sequence,temp,wb,n)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# @> 23 atoms and 1 coordinate set(s) were parsed in 0.00s.
# works
# f8a48599-c9a8-475a-9d1a-29b9f737bf57
# ade46d77-35b1-42c8-9161-f27295065131
# f0001e2d-86cc-4d85-bf71-6972284320e0
# af774bbc-cfe5-4bc7-a21e-c5d00cd112ba
# af774bbc-cfe5-4bc7-a21e-c5d00cd112ba
# 8653530a-c915-4418-858a-7f1758216d37
# af774bbc-cfe5-4bc7-a21e-c5d00cd112ba
# ...
