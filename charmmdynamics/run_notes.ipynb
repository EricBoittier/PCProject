# %%
print("hello")
s=["ALA","SER"]
t=["328","358","400"]
n="500000"

'''
i=1
ii="hello"
print(str(i)+ii)
'''
for ss in s:
    for tt in t:
        for ii in range(10):
            
            print("python", "1FirstExample.py", "-s", ss, "-n", n, "-t", tt, "-o", ss+"_"+str(ii+1)+"_"+tt+"K_gas")

    
#   python 1FirstExample.py -s GLY -n 500000 -t 298 -o GLY_10_298K_gas
print('Hello', 'World', sep='')
 #                 subprocess.call(["python", "script1", "-c", "config/config_file1.json", "-m", "import"])
    
    

    
'''
import subprocess
s=["ALA","SER"]
t=["328","358","400"]
n="500000"

for ss in s:
    for tt in t:
        for ii in range(10):
            subprocess.call(["python", "1FirstExample.py", "-s", ss, "-n", n, "-t", tt, "-o", ss+"_"+str(ii+1)+"_"+tt+"K_gas"])
            
import subprocess
s="ALA"
t="328"
n="500000"
print("hello")

for i in range(2):
    subprocess.call(["python", "1FirstExample.py", "-s", s, "-n", n, "-t", t, "-o", "test"+str(i+1)])
    print(["python", "1FirstExample.py", "-s", s, "-n", n, "-t", t, "-o", "test"+str(i+1)])
# Out:
# hello
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_1_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_2_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_3_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_4_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_5_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_6_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_7_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_8_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_9_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 328 -o ALA_10_328K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 358 -o ALA_1_358K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 358 -o ALA_2_358K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 358 -o ALA_3_358K_gas
# python 1FirstExample.py -s ALA -n 500000 -t 358 -o ALA_4_358K_gas
# ...
